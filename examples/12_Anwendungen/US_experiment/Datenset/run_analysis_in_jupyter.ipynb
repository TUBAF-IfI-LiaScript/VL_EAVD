# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url="https://raw.githubusercontent.com/TUBAF-IfI-LiaScript/VL_ProzeduraleProgrammierung/master/examples/12_Anwendungen/Datenset/distanceMeasurements_filtered.csv"

df=pd.read_csv(url, sep=',', header = 0)
df['date'] = pd.to_datetime(df['created_at'])
df['Temperature_diff']= (df["Temperature"].diff().abs() > 0.4) * 1
df.head(5)
# Out:
#                   created_at  Temperature   Humidity  US_duration  \
# 0  2023-01-06T16:44:36+00:00         12.6  69.800003       8610.0
# 1  2023-01-06T16:45:17+00:00         12.4  70.000000       8536.0
# 2  2023-01-06T16:45:58+00:00         12.3  70.400002       8413.0
# 3  2023-01-06T16:46:39+00:00         12.3  70.699997       8660.0
# 4  2023-01-06T16:47:19+00:00         12.3  70.900002       8366.0
#
#                        date  Temperature_diff
# 0 2023-01-06 16:44:36+00:00                 0
# 1 2023-01-06 16:45:17+00:00                 0
# 2 2023-01-06 16:45:58+00:00                 0
# 3 2023-01-06 16:46:39+00:00                 0
# 4 2023-01-06 16:47:19+00:00                 0

# %%
ax= df.plot(x="date", y="Temperature")
df.plot(x="date", y="Temperature_diff", ax= ax)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df["US_speed"] = (331.3 + (0.606 * df["Temperature"])) / 1000 / 1000 * 100
df["US_distance"] = df["US_duration"]*df["US_speed"] / 2

# %%
df.US_distance.describe()
# Out:
# count    39993.000000
# mean       144.437555
# std          1.155555
# min        139.379736
# 25%        143.611016
# 50%        144.469115
# 75%        145.349923
# max        148.903711
# Name: US_distance, dtype: float64

# %%
df["US_distance"].plot.hist(bins=25)
# Out:
# <AxesSubplot: ylabel='Frequency'>
